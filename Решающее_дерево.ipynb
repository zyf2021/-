# %% [markdown]
# <a href="https://colab.research.google.com/github/zyf2021/-/blob/main/%D0%A0%D0%B5%D1%88%D0%B0%D1%8E%D1%89%D0%B5%D0%B5_%D0%B4%D0%B5%D1%80%D0%B5%D0%B2%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree

# %%
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %%
from sklearn.datasets import load_wine
wine = load_wine()
X, y = wine.data, wine.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5657894736842105, 0.9166666666666666, 'X[12] <= 755.0\ngini = 0.658\nsamples = 178\nvalue = [59, 71, 48]'),
#  Text(0.34210526315789475, 0.75, 'X[11] <= 2.115\ngini = 0.492\nsamples = 111\nvalue = [2, 67, 42]'),
#  Text(0.21052631578947367, 0.5833333333333334, 'X[10] <= 0.935\ngini = 0.227\nsamples = 46\nvalue = [0, 6, 40]'),
#  Text(0.10526315789473684, 0.4166666666666667, 'X[6] <= 1.58\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.05263157894736842, 0.25, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39]'),
#  Text(0.15789473684210525, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3157894736842105, 0.4166666666666667, 'X[0] <= 13.515\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.2631578947368421, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.3684210526315789, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
# ...

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file = None)
graph = graphviz.Source(dot_data)
graph.render('wine')
# Out:
# 'wine.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=wine.feature_names,  
                      class_names=wine.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ###Plot Decision Tree with `dtreeviz` Package

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
# %config InlineBackend.figure_format = 'svg'  # Looks MUCH better than retina
# %config InlineBackend.figure_format = 'retina'

# %%
# !pip install dtreeviz

# %%
import dtreeviz
viz = dtreeviz.model(clf, 
               X, 
               y, 
               target_name = 'wine',
               feature_names = wine.feature_names,
               class_names = list(wine.target_names))
viz.view()
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
from dtreeviz import decision_boundaries

# %%
fig,axes = plt.subplots(1,1, figsize=(4,3))
decision_boundaries(clf, X, y, ax=axes, feature_names=['proline', 'flavanoid'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-166a8327775c> in <module>
#       1 fig,axes = plt.subplots(1,1, figsize=(4,3))
# ----> 2 decision_boundaries(clf, X, y, ax=axes, feature_names=['proline', 'flavanoid'])
#
# /usr/local/lib/python3.8/dist-packages/dtreeviz/classifiers.py in decision_boundaries(model, X, y, ntiles, tile_fraction, binary_threshold, show, feature_names, target_name, class_names, markers, boundary_marker, boundary_markersize, fontsize, fontname, dot_w, yshift, sigma, colors, ranges, figsize, ax)
#     129                                   ax=ax)
#     130     else:
# --> 131         raise ValueError(f"Expecting 2D data not {X.shape}")
#     132
#     133
#
# ValueError: Expecting 2D data not (178, 13)
